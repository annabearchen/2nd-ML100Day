# %%
作業1：

請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：

1. 你選的這組資料為何重要
我選的dataset為Bicycle Trip Data from Seattle's Cycle Share System。
透過這組資料，可以了解一個城市人民使用單車的習慣，進而規劃一個城市的交通建設計達到最有效率且低成本的交通計劃。

2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
資料是由Pronto Cycle Share提供，是西雅圖公共單車系統的交易記錄。

3. 蒐集而來的資料型態為何
資料型態主要為結構化資料，包含類別資料及時間序列資料。

4. 這組資料想解決的問題如何評估
透過這組資料可以了解一個城市主要的交通運輸情形及市民的交通路線。
以規劃最適合這個城市的交通計劃及發現既有的問題而進一步解決這個問題。



作業2：

想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
在哪些路段有更多的客源。

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
依載客目標去搜集不同的資料。
若是一個各交通點接駁來說，則是搜集各大車站進出旅客人數及列車抵達時間。
若是小型旅遊團客，則是搜集各大旅遊景點進出旅遊人數。
若是商務型乘客，則是搜集各大辦公商圈，載客點最多的地方以及商務客的路線。

3. 蒐集而來的資料型態為何
資料型態為非結構資料，例如載客路線。

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

例如在內湖園區最常的商務客可能是從不同的商務辦公區來的不同路線。
搜集各大車隊歷史的載客記錄，去規劃最好的路線。


作業3：
練習時間
請寫一個函式用來計算 Mean Square Error
MSE=1n∑ni=1(Yi−Ŷ i)2MSE=1n∑i=1n(Yi−Y^i)2 
Hint: 如何取平方

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
s=y_hat-y
MAE=sum(s**2)/101
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 204.819
